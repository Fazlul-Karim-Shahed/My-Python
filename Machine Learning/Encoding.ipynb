# %%
import pandas

# %%
ds = pandas.read_csv('car driving risk analysis.csv')

# %%
ds
# Out:
#     speed  risk
# 0     200  95.0
# 1      90  20.0
# 2     300  98.0
# 3     110  60.0
# 4     240  72.0
# 5     115  10.0
# 6      50   NaN
# 7     230  85.0
# 8     190  45.0
# 9     260  91.0
# 10    290  82.0
# 11    185  59.0
# 12    310  93.0
# 13     95  18.0
# 14     30   2.0
